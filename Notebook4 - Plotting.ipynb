# %% [markdown]
# # <a id='toc1_'></a>[Notebook4: Plotting in Python](#toc0_)

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Notebook4: Plotting in Python](#toc1_)
#   - [Matplotlib](#toc1_1_)
#   - [Plottypen](#toc1_2_)
#     - [Scatterplot](#toc1_2_1_)
#     - [Kuchenchart](#toc1_2_2_)
#     - [Area plot](#toc1_2_3_)
#     - [Histogramm](#toc1_2_4_)
#     - [Barplot (mit Anpassungen)](#toc1_2_5_)
#     - [Boxplots](#toc1_2_6_)
#   - [Erweiterung/Alternative: Seaborn](#toc1_3_)
#   - [Plotly](#toc1_4_)
#     - [Plotly Intro](#toc1_4_1_)
#     - [Plotly Graph Objects](#toc1_4_2_)
#     - [Advanced Plotting: 3D Vectors in plotly](#toc1_4_3_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ## <a id='toc1_1_'></a>[Matplotlib](#toc0_)

# %% [markdown]
# Matplotlib ist die standard Python-Bibliothek zur Erstellung von
# publikationsreifen Plots. Sie bietet eine Vielzahl von Funktionen zum
# Erstellen von verschiedenen Arten von Diagrammen wie Linien-, Balken-
# und Flächendiagrammen sowie Histogramme, Streudiagramme und mehr. Mit
# Matplotlib können Benutzer auch benutzerdefinierte Diagramme und
# Anpassungen vornehmen, um ihre Darstellungen zu optimieren. Die
# Bibliothek ist sehr flexibel und kann nahtlos mit anderen
# Python-Bibliotheken wie NumPy und Pandas integriert werden.

# %%
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Daten erstellen:

# %%
alter = [range(25, 35)] # Note: range(25, 35) wird nicht unpacked
alter = [*range(25, 35)] # range(25, 35) wird unpacked

# %% [markdown]
# Einschub:
# \* ist ein unpacking operator in python
#
# Der \* Operator unpacked die Elemente von iterable objects (=Objekte
# über deren Elemente man mit einem for-loop iterieren kann z.B. lists,
# tuples, strings..)

# %%
salary = np.around(np.random.normal(50000, 10000, 10), 0).tolist()

# %% [markdown]
# Erster einfacher Plot:

# %%
plt.plot(alter, salary)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Beschriftung hinzufügen:

# %%
plt.plot(alter, salary)
plt.xlabel("Alter")
plt.ylabel("Medianeinkommen")
plt.title("Medianeinkommen über Alter")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Verschiedene Gruppen plotten:

# %%
# Erstellung von weiteren Einkommensdaten:
salary_dt = salary
salary_sw = np.around(np.random.normal(60000, 5000, 10), 0).tolist()

# Plot beider Einkommensgruppen

plt.plot(alter, salary_dt, label="Deutschland")

plt.plot(alter, salary_sw, label="Schweiz")

plt.xlabel("Alter")
plt.ylabel("Medianeinkommen")
plt.title("Medianeinkommen über Alter")

plt.legend() # fügt die Legende auf Basis der Labels hinzu

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Modifizierung der Darstellung:

# %%
plt.plot(alter, salary_dt, label="Deutschland",
        color="pink", marker =".")

plt.plot(alter, salary_sw, label="Schweiz",
        linestyle = "--")

plt.xlabel("Alter")
plt.ylabel("Medianeinkommen")
plt.title("Medianeinkommen über Alter")

plt.legend() # fügt die Legende auf Basis der Labels hinzu
plt.grid(True) # fügt Gridlines hinzu
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Unterschiedliche Plot styles:

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use("tableau-colorblind10") # hier hier wird der ggplot stlye aktiviert

plt.plot(alter, salary_dt, label="Deutschland",
        marker =".")

plt.plot(alter, salary_sw, label="Schweiz",
        linestyle = "--")

plt.xlabel("Alter")
plt.ylabel("Medianeinkommen")
plt.title("Medianeinkommen über Alter")

plt.legend() # fügt die Legende auf Basis der Labels hinzu
plt.grid(True) # fügt Gridlines hinzu
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# deakiviere den ggplotsyle wieder:

plt.style.use("default") # hier hier wird der ggplot stlye aktiviert

# %% [markdown]
# Den plot speichern:

# %%
# plt.savefig("plot.png") saves the plot the the working directory

# %% [markdown]
# ## <a id='toc1_2_'></a>[Plottypen](#toc0_)

# %% [markdown]
# Nach diesem kurzen Into in Matplotlib betracheten wir nun ein paar der
# wichtigsten Plottypen die Matplotlib erstellen kann.
#
# Mit Blick darauf wie wir die die Daten generiert haben, ist der
# standard type der plot funktion "lineplot" nicht sinnvoll.
# Einen Scatterplot können wir einfach erstellen indem wir plt.plot zu
# plt.scatter ändern.

# %% [markdown]
# ### <a id='toc1_2_1_'></a>[Scatterplot](#toc0_)

# %%
plt.scatter(alter, salary_dt, label="Deutschland")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Diese Syntax funktiert gleich für andere Plottypen. Wichtige Plottypen
# sind:
#
# * Line Plot
# * Scatter Plot
# * Pie Plot
# * Area Plot
# * Histogram Plot
# * Bar Plot

# %% [markdown]
# Beispiele für den Lineplot und den Scatterplot haben wir schon gesehen,
# hier sind einfache Beispiele, für Pie-, Area-, und Histogram Plots
# ausgeschmücke Versonen der Plot finden sich
# [hier](https://www.w3schools.in/matplotlib/tutorials/plot-types).

# %% [markdown]
# ### <a id='toc1_2_2_'></a>[Kuchenchart](#toc0_)

# %%
#plt.style.use("seaborn")


slice = [12, 25, 50, 36, 19]
activities = ['NLP','Neural Network', 'Data analytics',
            'Quantum Computing', 'Machine Learning']

plt.pie(slice, labels = activities)

plt.show()

plt.style.use("default")

# %% [markdown]
# ### <a id='toc1_2_3_'></a>[Area plot](#toc0_)

# %%
# List of 7-days
days = [x for x in range(0, 7)]
 
# List of Suspected cases
Suspected = [12, 18, 35, 50, 72, 90, 100]
 
# List of Cured Cases
Cured = [4, 8, 15, 22, 41, 55, 62]
 
# List of Number of deaths
Deaths = [1, 3, 5, 7, 9, 11, 13]
 
# Plot x-labels, y-label and data
plt.plot([], [], color ='blue',
         label ='Suspected')
plt.plot([], [], color ='orange',
         label ='Cured')
plt.plot([], [], color ='brown',
         label ='Deaths')
 
# Implementing stackplot on data
plt.stackplot(days, Suspected, Cured,
              Deaths, baseline ='zero',
              colors =['blue', 'orange',
                       'brown'])
 
plt.legend()
 
plt.title('No of Cases')
plt.xlabel('Day of the week')
plt.ylabel('Overall cases')
 
plt.show()

# %% [markdown]
# Plots können übereinandergelegt werden:

# %%
plt.plot(alter, salary_dt, label="Deutschland",
        color="pink")

plt.plot(alter, salary_sw, label="Schweiz",
        linestyle = "--")

plt.scatter(alter, salary_dt, label="Deutschland Scat", color = "green")

plt.xlabel("Alter")
plt.ylabel("Medianeinkommen")
plt.title("Medianeinkommen über Alter")

plt.legend() # fügt die Legende auf Basis der Labels hinzu
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### <a id='toc1_2_4_'></a>[Histogramm](#toc0_)

# %%
pop = [22,55,62,45,21,22,34,42,42,4,2,8]
bins = [1,10,20,30,40,50]
plt.hist(pop, bins, rwidth=0.6)
plt.xlabel('age groups')
plt.ylabel('Number of people')
plt.title('Histogram')

# Print the chart
plt.show()

# %% [markdown]
# ### <a id='toc1_2_5_'></a>[Barplot (mit Anpassungen)](#toc0_)

# %% [markdown]
# Oft müssen Plots Datenstrukturen darstellen die über
# Standardarstellungen hinaus gehen. Wie genau eine bestimmte Darstellung
# erreicht werden kann hängt natürlich immer vom Einzellfall ab. Als
# Beispiel schauen wir uns einen Barplot an. Wir verwenden dazu den schon
# bekannten Datensatz zu Leihfahrädern
# ([Link](https://www.kaggle.com/competitions/bike-sharing-demand/data)).

# %%
import pandas as pd
bike_sharing = pd.read_csv("data/day.csv", sep = ",")

# %%
# Data cleaning (wie in der letzten Session):
bike_categories = ['season', 'holiday', 'weekday',
                    'workingday', 'weathersit']

for variable in bike_categories:
    bike_sharing[variable] = bike_sharing[variable].astype("category")

bike_sharing
# Out:
#      instant      dteday season  yr  mnth holiday weekday workingday  \
# 0          1  2011-01-01      1   0     1       0       6          0
# 1          2  2011-01-02      1   0     1       0       0          0
# 2          3  2011-01-03      1   0     1       0       1          1
# 3          4  2011-01-04      1   0     1       0       2          1
# 4          5  2011-01-05      1   0     1       0       3          1
# ..       ...         ...    ...  ..   ...     ...     ...        ...
# 726      727  2012-12-27      1   1    12       0       4          1
# 727      728  2012-12-28      1   1    12       0       5          1
# 728      729  2012-12-29      1   1    12       0       6          0
# 729      730  2012-12-30      1   1    12       0       0          0
# 730      731  2012-12-31      1   1    12       0       1          1
#
#     weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
bike_sharing['season'] = bike_sharing['season'].map({1: 'winter',
                                                    2: 'spring',
                                                    3: 'summer',
                                                    4: 'autumn'})
bike_sharing
# Out:
#      instant      dteday  season  yr  mnth holiday weekday workingday  \
# 0          1  2011-01-01  winter   0     1       0       6          0
# 1          2  2011-01-02  winter   0     1       0       0          0
# 2          3  2011-01-03  winter   0     1       0       1          1
# 3          4  2011-01-04  winter   0     1       0       2          1
# 4          5  2011-01-05  winter   0     1       0       3          1
# ..       ...         ...     ...  ..   ...     ...     ...        ...
# 726      727  2012-12-27  winter   1    12       0       4          1
# 727      728  2012-12-28  winter   1    12       0       5          1
# 728      729  2012-12-29  winter   1    12       0       6          0
# 729      730  2012-12-30  winter   1    12       0       0          0
# 730      731  2012-12-31  winter   1    12       0       1          1
#
#     weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %% [markdown]
# Wir wollen für die vier Jahreszeiten die Fahrrad Ausleihzahlen von
# casual und registrierten Nutzern gegenüberstellen.

# %%
# X-Achse:
season = bike_sharing["season"].cat.categories
print(season)
# Out:
# Index([1, 2, 3, 4], dtype='int64')

# %%
# Y-Achse:

casual = bike_sharing.groupby("season")["casual"].sum()
registered = bike_sharing.groupby("season")["registered"].sum()
casual
# Out:
# C:\Users\adria\AppData\Local\Temp\ipykernel_20776\1912612672.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   casual = bike_sharing.groupby("season")["casual"].sum()
# C:\Users\adria\AppData\Local\Temp\ipykernel_20776\1912612672.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   registered = bike_sharing.groupby("season")["registered"].sum()
# season
# 1     60622
# 2    203522
# 3    226091
# 4    129782
# Name: casual, dtype: int64

# %%
counts = pd.concat([casual, registered], axis=1)
counts
# Out:
#         casual  registered
# season
# 1        60622      410726
# 2       203522      715067
# 3       226091      835038
# 4       129782      711831

# %% [markdown]
# Wenn wir die Plots übereinander legen erreichen wir nicht den
# geschünschten Effekt einer Gegenüberstellung. Die Bars werden
# aufeinander gelegt:

# %%
plt.bar(x = season, height = counts["registered"])
plt.bar(x = season, height = counts["casual"])
plt.xlabel('Jahreszeit')
plt.ylabel('Ausleihzahlen')
plt.title('Histogram')

# Print the chart
plt.show()

# %% [markdown]
# Um die Bars voneinander zu trennen müssen wir etwas in die Trickkiste
# greifen:

# %%
x_indexes = np.arange(len(season))
width = 0.25
loc = 0.25/2

with plt.xkcd():

        plt.bar(x = x_indexes - loc,
                height = counts["registered"],
                color = "purple",
        width = width)
        plt.bar(x = x_indexes + loc,
                height = counts["casual"],
                color = "green", 
                width=width)
        
plt.xlabel('Jahreszeit')
plt.ylabel('Ausleihzahlen')
plt.title('Histogram')

plt.xticks(ticks=x_indexes, labels=season)
# Out:
# ([<matplotlib.axis.XTick at 0x216fbb34320>,
# ...
#  [Text(0, 0, '1'), Text(1, 0, '2'), Text(2, 0, '3'), Text(3, 0, '4')])
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %% [markdown]
# ### <a id='toc1_2_6_'></a>[Boxplots](#toc0_)

# %%
import seaborn as sns

# Laden des Iris Dataset (bekannt aus R, Teil des Seaborn Packets)
dataset = sns.load_dataset('iris')
dataset.columns = ["sepal length (cm)",
                    "sepal width (cm)",
                    "petal length (cm)",
                    "petal width (cm)",
                    "species"]
# heading of the dataset
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 import seaborn as sns
#       3 # Laden des Iris Dataset (bekannt aus R, Teil des Seaborn Packets)
#       4 dataset = sns.load_dataset('iris')
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# Boxplot:

plt.boxplot(dataset['petal length (cm)'])
plt.show()

# %% [markdown]
# ## <a id='toc1_3_'></a>[Erweiterung/Alternative: Seaborn](#toc0_)

# %% [markdown]
# Das Seaborn package ist eine Erweitung bzw. Alternative Matplotlib die
# auf Matplotlib basiert. Seaborne funktioniert besser mit pandas data
# frames. Die Seaborn syntax ist im gleich zu matplotlib oft kürzer und
# einfacher.

# %% [markdown]
# Seaborn Beispiel: Histogram + Kernel Density Estimation (KDE):

# %%
sns.displot(data=dataset, x='petal length (cm)', bins=10, kde=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 sns.displot(data=dataset, x='petal length (cm)', bins=10, kde=True)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# Will man eine Normalverteilung mit Parametern basierend auf den Daten
# hinzufügen muss man etwas kreativ werden:

# %%
from scipy import stats

def normal(mean, std, color="black"):
    x = np.linspace(mean-3*std, mean+3*std, 200) # erstelle X-Koords
    p = stats.norm.pdf(x, mean, std) # Norm Density Werte der X-Koords
    z = plt.plot(x, p, color, linewidth=2) # Verbinde Density Werte

# %%
mean = dataset["petal length (cm)"].mean()
std = dataset["petal length (cm)"].std()

dataset["sd"] = (dataset[
    "petal length (cm)"] - mean) / std

sns.displot(data=dataset,
            x="sd",
            kde=True, stat = "probability", discrete = True)
normal(0, 1)

# %% [markdown]
# ## <a id='toc1_4_'></a>[Plotly](#toc0_)

# %% [markdown]
# Eine weitere Alternative zur Datenvisualisierung ist das Plotly Packet.
# Plotly ist deutlich neuer als Matplotlib. Je nachdem was man macht
# eignet sich die eine oder die andere Library besser. Wer gehen nicht
# näher auf die Unterschiede ein. Gernerell lässt sich sagen, dass plotly
# deutlich besser für interaktive Plots geeignet ist. Bevor wir starten
# können müssen wir cufflinks über .cmd installieren:
#
# <code>conda install -c conda-forge cufflinks-py</code>.
#
# Die Option -c im conda install Befehl gibt an, welcher Kanal für die
# Installation des Pakets verwendet werden soll.
#
# In unserem Fall ist der angegebene Kanal conda-forge. Conda-Kanäle sind
# Online-Repositories von Paketen, die wir verwenden können, um Software
# auf unserem System zu installieren. conda-forge ist eine von der
# Community geleitete Sammlung von Paketen, die von Mitwirkenden aus der
# ganzen Welt gepflegt wird.
#
# Wenn wir die -c Option im conda install Befehl verwenden, sucht Conda
# nach dem Paket im angegebenen Kanal anstelle des Standardkanals.
#
# Daher sucht Conda in diesem Fall nach dem Paket cufflinks-py im
# conda-forge Kanal und lädt es herunter und installiert es, wenn es
# verfügbar ist.

# %%
import chart_studio.plotly as py
import cufflinks as cf # verbindet plotly mit pandas
import plotly.express as px # plotly express
import plotly.graph_objects as go #plotly go

# %% [markdown]
# plotly.offline - plotly.offline - Dieses Modul ermöglicht es
# plotly, im Offline-Modus laufen zu lassen, indem es
# JavaScript-Bibliotheken herunterlädt und in die
# Jupyter-Kernel-Umgebung einbindet.
#
# graph_objects - Jeder Graph ist ein Objekt. Dieses Modul enthält
# Funktionen, die Graph-Objekte erzeugen.

# %% [markdown]
# ### <a id='toc1_4_1_'></a>[Plotly Intro](#toc0_)

# %% [markdown]
# Wir starten mit einem simplen lineplot der salary data und mergen unsere
# Einkommensdaten in einem pandas DataFrame:

# %%
sal_dict = {"alter":alter, "dt":salary_dt, "sw":salary_sw}
df_salary = pd.DataFrame(sal_dict)
df_salary.head(5)
# Out:
#    alter       dt       sw
# 0     25  50565.0  53963.0
# 1     26  54013.0  58980.0
# 2     27  47023.0  52975.0
# 3     28  41082.0  58229.0
# 4     29  60811.0  66009.0

# %% [markdown]
# Wir sehen uns die Daten in einem einfachen plotly express
# Scatterplot an:

# %%
px.scatter(df_salary,
        x="alter",
        y=["dt","sw"])

# %% [markdown]
# Als Kontrast, der selbe plot mit matplotlib:

# %%
sal_plot_mat = df_salary.plot(x = "alter", y = ["dt"], kind  = "scatter")
df_salary.plot(x = "alter",
                y = ["sw"],
                color = "red",
                kind  = "scatter",
                ax = sal_plot_mat)

plt.show()
# Notes: Wir nutzen hier die pandas .plot() method, welche wiederum auf 
# matplotlib als backend zugreift. 
# der ax parameter beschreibt die x-Achse auf die geplottet wird. Um 
# die neuen (roten) Punkte.

# %% [markdown]
# Interessanterweise kann pandas nicht nur matplotlib zur Darstellung des
# plots nutzen, sondern mit dem parameter "backend = "plotly"" auch auf
# Plotly zugreifen. Die Erstellung von zwei plots und der Verweiß auf
# die X-Achse des ersten Plots ist dann nicht nötig.

# %%
sal_plot_px = df_salary.plot(x = "alter",
                            y = ["dt", "sw"],
                            backend="plotly")
sal_plot_px

# %% [markdown]
# ### <a id='toc1_4_2_'></a>[Plotly Graph Objects](#toc0_)

# %% [markdown]
# px.plot ist der schnelle weg um eine plotly Object zu erstellen.
# Wollen wir ein plotly object detailiert manipulieren, nutzen wir die
# plotly.graph_objects library bzw. plotly go.Figure() funktion.

# %%
# Wir ziehen uns den Stock Bsp. Datensatz aus dem plotly Paket:
df_stocks = px.data.stocks()

# Erstellt eine Figure, die wir dann mit plots füllen:
fig = go.Figure()
# Scatterpunkte über individuelle columns hinzufügen:
fig.add_trace(go.Scatter(x=df_stocks.date, y=df_stocks.AAPL, 
                        mode='lines', name='Apple'))
fig.add_trace(go.Scatter(x=df_stocks.date, y=df_stocks.AMZN, 
                        mode='lines+markers', name='Amazon'))
# You can create custom lines (Dashes : dash, dot, dashdot)
fig.add_trace(go.Scatter(x=df_stocks.date, y=df_stocks.GOOG, 
                        mode='lines+markers', name='Google',
                        line=dict(color='firebrick', width=2,
                                dash='dashdot')))
# Mehr styling:
fig.update_layout(title='Stock Price Data 2018 - 2020',
                xaxis_title='Price', yaxis_title='Date')

# Go crazy styling the figure
fig.update_layout(
    # X-Achse manipulieren:
    xaxis=dict(
        showline=True,
        showgrid=False,
        showticklabels=True,
        linecolor='rgb(204, 204, 204)',
        linewidth=2,
        ticks='outside',
        tickfont=dict(
            family='Arial',
            size=12,
            color='rgb(82, 82, 82)',
        ),
    ),
    # Y-Achse abschalten:
    yaxis=dict(
        showgrid=False,
        zeroline=False,
        showline=False,
        showticklabels=False,
    ),
    autosize=False, # Plotgröße selbst festlegen
    margin=dict(
        autoexpand=False,
        l=100,
        r=20,
        t=110,
    ),
    showlegend=False,
    plot_bgcolor='white'
)

# %% [markdown]
# Dieses Bsp. ist aus folgendem Github Profil entnommen
# ([Link](https://github.com/derekbanas/plotly-tutorial/blob/master/Plotly%20Tut.ipynb)).
# Dort finden sich weitere Beispiele zu plotly.

# %% [markdown]
# ### <a id='toc1_4_3_'></a>[Advanced Plotting: 3D Vectors in plotly](#toc0_)

# %% [markdown]
# Das Plotten komplizierer Daten erfodert eine tiefere Auseinandersetzung
# mit der Syntax von plotly. Im folgenden Beispiel werden wir die
# Basisvektoren einer 3x3 Matrix zu plotten.
#
# Angenommen wir haben folgende Matrix:
#
# $\begin{pmatrix}
#  2 & 1 & 0 \\
#  1 & 1 & 1 \\
#  3 & 2 & 2 \\
# \end{pmatrix}$
#
# Wie können wir plotly nutzen um die 3 Basisvektoren:
#
# $a = \begin{pmatrix}2 \\ 1 \\ 3 \\\end{pmatrix}$;
# $b = \begin{pmatrix}1 \\ 1 \\ 2 \\\end{pmatrix}$;
# $c = \begin{pmatrix}0 \\ 1 \\ 2 \\\end{pmatrix}$
#
# plotten?

# %%
import numpy as np

# %%
matrix = np.array([[2,1,0],[1,1,1],[3,2,2]])

# %%
a = matrix[:,0]
b = matrix[:,1]
c = matrix[:,2]

# %% [markdown]
# Ursprung (hier Nullvektor) erstellen:

# %%
Nv = np.array([0,0,0])

# %% [markdown]
# Koordinaten auf Basis der Vektoren bestimmen

# %%
Coords = np.stack([Nv,a,Nv,b,Nv,c], axis = 1)

# %%
x = Coords[0].tolist() # Liste der X-Koords aller Punkte
y = Coords[1].tolist() # Liste der Y-Koords aller Punkte
z = Coords[2].tolist() # Liste der Z-Koords aller Punkte

# %%
pairs = [(0,1), (2,3),(4,5)]
pairs
# Out:
# [(0, 1), (2, 3), (4, 5)]

# %% [markdown]
# Folgender Code zieht die Startkoordinaten der Vektoren aus den
# Koordinatenvektoren heraus:

# %%
x_m = [x[p[0]] for p in pairs]
y_m = [y[p[0]] for p in pairs]
z_m = [z[p[0]] for p in pairs]

# %%
trace1 = go.Scatter3d(
    x=x_m, #X-Koords der Scatterpunkte
    y=y_m, #Y-Koords der Scatterpunkte
    z=z_m, #Z-Koords der Scatterpunkte
    mode='markers',
    name='markers',
    line=dict(color='green'),
    marker=dict(size = 2)
)

# fig = go.Figure(trace1) # trace1 (3 überlapp. Punkte im Coord Ursp.)
# fig.show() # trace1 anschauen

# %%
# Initiere Listen für die Vektorlinien:
x_lines = list()
y_lines = list()
z_lines = list()

# Speichere alle x,y,z coords in einer liste, füge nach jedem 
# Punktepärchen ein "None" hinzu:

for p in pairs: # (0,1), (2,3), (4,5) # Wählt Punktepärchen aus
    for i in range(2): # 0, 1 # Wählt ersten, dann zweiten Punkt
        x_lines.append(x[p[i]])
        y_lines.append(y[p[i]])
        z_lines.append(z[p[i]])

print(x_lines)
# Out:
# [0, 2, 0, 1, 0, 0]

# %% [markdown]
# Mit den "lines" Listen initialisieren wir jetzt eine trace für die
# Vektorlinien:

# %%
trace2 = go.Scatter3d(
    x=x_lines,
    y=y_lines,
    z=z_lines,
    mode='lines',
    line = dict(width = 2, color = 'rgb(255, 0,0)')
)

# fig = go.Figure(trace2) 
# fig.show() # trace2

# %% [markdown]
# Kurzer Blick was wir bisher geschafft haben:

# %%
fig = go.Figure(data=[trace1, trace2])
fig.show()

# %% [markdown]
# Die Spitzen der Vektoren fehlen noch. Die
# <code>go.Cone()</code> trace könnte hier passend sein. Dazu müssen wir
# zunächst verstehen wie die Cone trace funktioniert. In der
# Dokumentation finden wir folgendes Statement:
#
# "Use cone traces to visualize vector fields. Specify a vector field
# using 6 1D arrays, 3 position arrays x, y and z and 3 vector component
# arrays u, v, w. The cones are drawn exactly at the positions given
# by x, y and z."
#
# Wir starten mit einer einfachen Cone um herauszufinden ob sich alles
# so verhält wie wir uns das vorstellen:

# %%
cone_test = go.Figure(data=go.Cone(x=[0], y=[0], z=[0],
                                    u=[1], v=[0], w=[0]))

cone_test.show()

# %% [markdown]
# Wir stellen ein Problem fest: es scheint als würde die Cone nicht auf
# den Koordinaten (0,0,0) beginnen (Boden) oder aufhören (Spitze).
# Wir versuchen die Problematik zu verdeutlichen:

# %%
cone_test = go.Figure(data=go.Cone(x=[0], y=[0], z=[0],
                                    u=[1], v=[0], w=[0],
                                    opacity = 0.5))

cone_test.add_trace(go.Scatter3d(
    x = [0], y = [0], z = [0],
    marker=dict(color = "black")
))

cone_test.show()

# %% [markdown]
# Ein weiterer Blick in die Dokumentation offenbart, dass der Parameter
# "anchor" den Punkt der Cone referenziert der durch x,y,z fixiert wird.
# Default ist hier "cm" (center of mass), wir stellen auf "tail" um:

# %%
cone_test = go.Figure(data=go.Cone(x=[0], y=[0], z=[0],
                                    u=[1], v=[0], w=[0],
                                    opacity = 0.5, 
                                    anchor="tail"))

cone_test.add_trace(go.Scatter3d(
    x = [0], y = [0], z = [0],
    marker=dict(color = "black")
))

cone_test.show()

# %% [markdown]
# Das sieht besser aus. Wir erkennen jetzt jedoch, dass die Länge der
# Cone nicht 1 ist, obwohl der Vektorfeld Vektor (1,0,0) ist. Ein
# weiterer Blick in die Dkoumentation zeigt, dass die Länge der Cone
# standardisiert ist. Wir ändern die entsprechenden Parameter:

# %%
cone_test = go.Figure(data=go.Cone(x=[0], y=[0], z=[0],
                                    u=[1], v=[0], w=[0],
                                    opacity = 0.5, 
                                    anchor="tail",
                                    sizemode = "absolute",
                                    sizeref=1))

cone_test.add_trace(go.Scatter3d(
    x = [0], y = [0], z = [0],
    marker=dict(color = "black")
))

cone_test.add_trace(go.Scatter3d(
    x = [0,1], y = [0,0], z = [0,0],
    mode = "lines",
    line = dict(width = 3, color = 'black')
))

cone_test.show()

# %% [markdown]
# Die Cone verhält sich nun genauso wie erwartet. Mit dem nun gewonnenen
# Verstädnis über go.Cone() funktion, können wir unsere Vektoren
# vervollständigen:

# %%
arrow_tip_ratio = 0.1
arrow_starting_ratio = 0.98

x = Coords[0].tolist() # Liste der X-Koords aller Punkte
y = Coords[1].tolist() # Liste der Y-Koords aller Punkte
z = Coords[2].tolist() # Liste der Z-Koords aller Punkte

# Der loop nimmt die Startkoordinaten jeder Dimension eines jeden 
# Vektors (e.g.: x[p[0]]) und addiert die 98% der Länge. Somit starten
# die Cones 2% vor der Spitze des Vektors.
    
# Der zweite teil des loop skaliert die Vektoren runter auf 0.1%, für 
# das Vektorfeld der Cones.

for p in pairs:
    fig.add_trace(go.Cone(
        x=[x[p[0]] + arrow_starting_ratio*(x[p[1]] - x[p[0]])],
        y=[y[p[0]] + arrow_starting_ratio*(y[p[1]] - y[p[0]])],
        z=[z[p[0]] + arrow_starting_ratio*(z[p[1]] - z[p[0]])],
        u=[arrow_tip_ratio*(x[p[1]] - x[p[0]])],
        v=[arrow_tip_ratio*(y[p[1]] - y[p[0]])],
        w=[arrow_tip_ratio*(z[p[1]] - z[p[0]])],
        showlegend=False,
        showscale=False,
        autocolorscale=False,
        colorscale=[[0, 'rgb(255,0,0)'], [1, 'rgb(255,0,0)']],
        anchor="tail",
        sizemode = "absolute",
        sizeref=0.1
        ))

fig.show()

# %% [markdown]
# Das sieht gut aus. Abschließend wollen wir alles in einer Funktion
# zusammenfügen und die Farben ändern:

# %%
def Basisvectors(m,
                arrow_tip_ratio,
                arrow_starting_ratio):

    fig = go.Figure()

    a = m[:,0]
    b = m[:,1]
    c = m[:,2]

    Nv = np.array([0,0,0])

    Coords = np.stack([Nv,a,Nv,b,Nv,c], axis = 1)

    x = Coords[0].tolist() # Liste der X-Koords aller Punkte
    y = Coords[1].tolist() # Liste der Y-Koords aller Punkte
    z = Coords[2].tolist() # Liste der Z-Koords aller Punkte

    pairs = [(0,1), (2,3),(4,5)]

    x_m = [x[p[0]] for p in pairs]
    y_m = [y[p[0]] for p in pairs]
    z_m = [z[p[0]] for p in pairs]

    trace1 = go.Scatter3d(
        x=x_m, #X-Koords der Scatterpunkte
        y=y_m, #Y-Koords der Scatterpunkte
        z=z_m, #Z-Koords der Scatterpunkte
        mode='markers',
        name='markers',
        line=dict(color='black'),
        marker=dict(size = 2)
    )

    fig.add_trace(trace1)

    col = ["green", "none", "red", "none", "blue", "none"]

    x_lines = list()
    y_lines = list()
    z_lines = list()

    for p in pairs: # (0,1), (2,3), (4,5) # Wählt Punktepärchen aus
        for i in range(2): # 0, 1 # Wählt ersten, dann zweiten Punkt
            x_lines.append(x[p[i]])
            y_lines.append(y[p[i]])
            z_lines.append(z[p[i]])

    for p in pairs:
        trace2 = go.Scatter3d(
            x=x_lines[p[0]:(p[1]+1)],
            y=y_lines[p[0]:(p[1]+1)],
            z=z_lines[p[0]:(p[1]+1)],
            opacity=0.5,
            mode='lines',
            line = dict(width = 2, color = col[p[0]])
        )
        fig.add_trace(trace2)
    
    for p in pairs:
        fig.add_trace(go.Cone(
            x=[x[p[0]] + arrow_starting_ratio*(x[p[1]] - x[p[0]])],
            y=[y[p[0]] + arrow_starting_ratio*(y[p[1]] - y[p[0]])],
            z=[z[p[0]] + arrow_starting_ratio*(z[p[1]] - z[p[0]])],
            u=[arrow_tip_ratio*(x[p[1]] - x[p[0]])],
            v=[arrow_tip_ratio*(y[p[1]] - y[p[0]])],
            w=[arrow_tip_ratio*(z[p[1]] - z[p[0]])],
            showlegend=False,
            showscale=False,
            autocolorscale=False,
            colorscale=[[0, col[p[0]]], [1, col[p[0]]]],
            anchor="tail",
            sizemode = "absolute",
            sizeref=0.1,
            opacity=0.5
            ))
    
    fig.show()

# %%
mat = np.array([[1,2,5],[2,4,2],[3,6,1]])
mat
# Out:
# array([[1, 2, 5],
#        [2, 4, 2],
#        [3, 6, 1]])

# %%
mat_t = mat.transpose()
mat_t

# %%
Basisvectors(mat, 0.1, 0.98)
